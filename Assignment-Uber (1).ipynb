# %% [markdown]
# # **Assignment on Uber dataset**

# %% [markdown]
# **Load the dataset**

# %%
import pandas as pd
uber_data = pd.read_csv("Uber.csv")
uber_data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %% [markdown]
# **Display basic info about dataset**

# %%
uber_data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
uber_data.head(10)
# Out:
#        START_DATE*        END_DATE* CATEGORY*           START*  \
# 0   1/1/2016 21:11   1/1/2016 21:17  Business      Fort Pierce
# 1    1/2/2016 1:25    1/2/2016 1:37  Business      Fort Pierce
# 2   1/2/2016 20:25   1/2/2016 20:38  Business      Fort Pierce
# 3   1/5/2016 17:31   1/5/2016 17:45  Business      Fort Pierce
# 4   1/6/2016 14:42   1/6/2016 15:49  Business      Fort Pierce
# 5   1/6/2016 17:15   1/6/2016 17:19  Business  West Palm Beach
# 6   1/6/2016 17:30   1/6/2016 17:35  Business  West Palm Beach
# 7   1/7/2016 13:27   1/7/2016 13:33  Business             Cary
# 8   1/10/2016 8:05   1/10/2016 8:25  Business             Cary
# 9  1/10/2016 12:17  1/10/2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# 4  West Palm Beach    63.7   Customer Visit
# ...

# %%
uber_data.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
uber_data.shape
# Out:
# (1156, 7)

# %%
uber_data.describe()
# Out:
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
uber_data.info()
uber_data.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %% [markdown]
# **Check for missing values**

# %%
uber_data.isnull()
# Out:
#       START_DATE*  END_DATE*  CATEGORY*  START*  STOP*  MILES*  PURPOSE*
# 0           False      False      False   False  False   False     False
# 1           False      False      False   False  False   False      True
# 2           False      False      False   False  False   False     False
# 3           False      False      False   False  False   False     False
# 4           False      False      False   False  False   False     False
# ...           ...        ...        ...     ...    ...     ...       ...
# 1151        False      False      False   False  False   False     False
# 1152        False      False      False   False  False   False     False
# 1153        False      False      False   False  False   False     False
# 1154        False      False      False   False  False   False     False
# 1155        False       True       True    True   True   False      True
#
# [1156 rows x 7 columns]

# %%
uber_data.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
uber_data.isnull()
# Out:
#       START_DATE*  END_DATE*  CATEGORY*  START*  STOP*  MILES*  PURPOSE*
# 0           False      False      False   False  False   False     False
# 2           False      False      False   False  False   False     False
# 3           False      False      False   False  False   False     False
# 4           False      False      False   False  False   False     False
# 5           False      False      False   False  False   False     False
# ...           ...        ...        ...     ...    ...     ...       ...
# 1150        False      False      False   False  False   False     False
# 1151        False      False      False   False  False   False     False
# 1152        False      False      False   False  False   False     False
# 1153        False      False      False   False  False   False     False
# 1154        False      False      False   False  False   False     False
#
# [653 rows x 7 columns]

# %% [markdown]
# **Drop rows with missing values**

# %%
uber_data=uber_data.dropna()
uber_data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %% [markdown]
# **fill missing values (propose column with unknown value)**

# %%
uber_data.loc[:, 'CATEGORY*'] = uber_data['CATEGORY*'].fillna('Unknown')
uber_data.loc[:,'STOP*'] = uber_data['STOP*'].fillna('Unknown Location')
uber_data.loc[:,'PURPOSE*'] = uber_data['PURPOSE*'].fillna('Unknown Purpose')
uber_data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %%
uber_data.isnull().sum()
# Out:
# START_DATE*    0
# END_DATE*      0
# CATEGORY*      0
# START*         0
# STOP*          0
# MILES*         0
# PURPOSE*       0
# dtype: int64

# %% [markdown]
# **Check and remove duplicates**

# %%
unique_dates = uber_data['START_DATE*'].unique()
unique_dates
# Out:
# array(['1/1/2016 21:11', '1/2/2016 20:25', '1/5/2016 17:31',
#        '1/6/2016 14:42', '1/6/2016 17:15', '1/6/2016 17:30',
#        '1/7/2016 13:27', '1/10/2016 8:05', '1/10/2016 12:17',
#        '1/10/2016 15:08', '1/10/2016 18:18', '1/10/2016 19:12',
#        '1/11/2016 8:55', '1/11/2016 11:56', '1/11/2016 13:32',
#        '1/11/2016 14:30', '1/12/2016 12:33', '1/12/2016 12:53',
#        '1/12/2016 14:42', '1/12/2016 15:13', '1/12/2016 15:42',
#        '1/12/2016 16:02', '1/13/2016 13:54', '1/13/2016 15:00',
#        '1/14/2016 16:29', '1/14/2016 21:39', '1/15/2016 0:41',
#        '1/15/2016 11:43', '1/15/2016 13:26', '1/18/2016 14:55',
#        '1/18/2016 16:13', '1/19/2016 10:55', '1/20/2016 10:36',
#        '1/20/2016 11:48', '1/20/2016 13:25', '1/21/2016 14:25',
#        '1/21/2016 14:43', '1/21/2016 16:01', '1/26/2016 10:41',
#        '1/26/2016 12:33', '1/26/2016 16:24', '1/26/2016 17:17',
#        '1/26/2016 17:27', '1/27/2016 9:24', '1/27/2016 10:19',
# ...

# %%
duplicate_dates = uber_data['START_DATE*'].duplicated().sum() #.duplicated checks
duplicate_dates
# Out:
# 1

# %%
uber_data = uber_data.drop_duplicates() #drop duplicates
uber_data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business   West Palm Beach
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %%
duplicates = uber_data[uber_data.duplicated()].sum()
duplicates
# Out:
# START_DATE*      0
# END_DATE*        0
# CATEGORY*        0
# START*           0
# STOP*            0
# MILES*         0.0
# PURPOSE*         0
# dtype: object

# %% [markdown]
# **Convert START_DATE and END_DATE to datetime**

# %%
uber_data.loc[:,'START_DATE*'] = pd.to_datetime(uber_data['START_DATE*'],errors='coerce')
uber_data.dtypes
# Out:
# START_DATE*    datetime64[ns]
# END_DATE*              object
# CATEGORY*              object
# START*                 object
# STOP*                  object
# MILES*                float64
# PURPOSE*               object
# dtype: object

# %%
uber_data.loc[:, 'END_DATE*'] = pd.to_datetime(uber_data['END_DATE*'], errors='coerce')
uber_data.dtypes
# Out:
# START_DATE*    datetime64[ns]
# END_DATE*      datetime64[ns]
# CATEGORY*              object
# START*                 object
# STOP*                  object
# MILES*                float64
# PURPOSE*               object
# dtype: object

# %% [markdown]
# **Total number of rides per category:**

# %%
rides = uber_data.groupby('CATEGORY*').size()
rides
# Out:
# CATEGORY*
# Business    646
# Personal      6
# dtype: int64

# %% [markdown]
# **Total miles traveled for each purpose:**

# %%
miles_travelled = uber_data.groupby('PURPOSE*')['MILES*'].sum()
miles_travelled
# Out:
# PURPOSE*
# Airport/Travel       16.5
# Between Offices     197.0
# Charity ($)          15.1
# Commute             180.2
# Customer Visit     2089.5
# Errand/Supplies     508.0
# Meal/Entertain      911.7
# Meeting            2841.4
# Moving               18.2
# Temporary Site      523.7
# Name: MILES*, dtype: float64

# %% [markdown]
# **Average distance for business vs. personal rides:**

# %%
business_miles = uber_data.groupby('CATEGORY*')['MILES*'].agg(['sum','mean','max'])
business_miles
# Out:
#               sum       mean    max
# CATEGORY*
# Business   7087.8  10.971827  310.3
# Personal    213.5  35.583333  180.2

# %% [markdown]
# **Add a column for cost estimation (assuming $2 per mile):**

# %%
import numpy as np
#uber_data['cost']= np.where(uber_data['MILES*'] > 0,uber_data['MILES*']*2,0) getting warning
uber_data.loc[:, 'cost'] = np.where(uber_data['MILES*'] > 0, uber_data['MILES*'] * 2, 0)
uber_data.head(10)
# Out:
#            START_DATE*           END_DATE* CATEGORY*           START*  \
# 0  2016-01-01 21:11:00 2016-01-01 21:17:00  Business      Fort Pierce
# 2  2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 3  2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 4  2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 5  2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
# 6  2016-01-06 17:30:00 2016-01-06 17:35:00  Business  West Palm Beach
# 7  2016-01-07 13:27:00 2016-01-07 13:33:00  Business             Cary
# 8  2016-01-10 08:05:00 2016-01-10 08:25:00  Business             Cary
# 9  2016-01-10 12:17:00 2016-01-10 12:44:00  Business          Jamaica
# 10 2016-01-10 15:08:00 2016-01-10 15:51:00  Business         New York
#
#               STOP*  MILES*         PURPOSE*   cost
# 0       Fort Pierce     5.1   Meal/Entertain   10.2
# 2       Fort Pierce     4.8  Errand/Supplies    9.6
# ...

# %% [markdown]
# **Filter rides longer than 50 miles:**

# %%
longer_miles = uber_data[uber_data['MILES*'] >50]
longer_miles
# Out:
#              START_DATE*           END_DATE* CATEGORY*         START*  \
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business    Fort Pierce
# 232  2016-03-17 12:52:00 2016-03-17 15:11:00  Business         Austin
# 251  2016-03-19 19:33:00 2016-03-19 20:39:00  Business      Galveston
# 268  2016-03-25 13:24:00 2016-03-25 16:22:00  Business           Cary
# 269  2016-03-25 16:52:00 2016-03-25 22:22:00  Business          Latta
# 270  2016-03-25 22:54:00 2016-03-26 01:39:00  Business   Jacksonville
# 295  2016-04-02 12:21:00 2016-04-02 14:47:00  Business      Kissimmee
# 296  2016-04-02 16:57:00 2016-04-02 18:09:00  Business  Daytona Beach
# 297  2016-04-02 19:38:00 2016-04-02 22:36:00  Business   Jacksonville
# 298  2016-04-02 23:11:00 2016-04-03 01:34:00  Business      Ridgeland
# 299  2016-04-03 02:00:00 2016-04-03 04:16:00  Business       Florence
# 559  2016-07-17 12:20:00 2016-07-17 15:25:00  Personal          Boone
# ...

# %% [markdown]
# **Filter by specific purpose (e.g., meetings):**

# %%
purpose_filter = uber_data[uber_data['PURPOSE*'] == "Meeting"]
purpose_filter
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 6    2016-01-06 17:30:00 2016-01-06 17:35:00  Business   West Palm Beach
# 7    2016-01-07 13:27:00 2016-01-07 13:33:00  Business              Cary
# 8    2016-01-10 08:05:00 2016-01-10 08:25:00  Business              Cary
# 10   2016-01-10 15:08:00 2016-01-10 15:51:00  Business          New York
# ...                  ...                 ...       ...               ...
# 1142 2016-12-29 20:15:00 2016-12-29 20:45:00  Business           Kar?chi
# 1144 2016-12-29 23:14:00 2016-12-29 23:47:00  Business  Unknown Location
# 1148 2016-12-30 16:45:00 2016-12-30 17:08:00  Business           Kar?chi
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
#
#                  STOP*  MILES* PURPOSE*  cost
# ...

# %% [markdown]
# **What is the total number of business trips versus personal trips?**

# %%
business_trip_count = uber_data[uber_data['CATEGORY*'] == 'Business'].shape
business_trip_count
# Out:
# (646, 8)

# %%
personal_trip_count = uber_data[uber_data['CATEGORY*'] == 'Personal'].shape
personal_trip_count
# Out:
# (6, 8)

# %% [markdown]
# **What percentage of trips are business versus personal?**

# %%
category_counts = uber_data['CATEGORY*'].value_counts()

total_trips = category_counts.sum()

business_percentage = (category_counts.get('Business', 0) / total_trips) * 100
business_percentage
# Out:
# 99.079754601227

# %%
personal_percentage = (category_counts.get('Personal', 0) / total_trips) * 100
personal_percentage
# Out:
# 0.9202453987730062
